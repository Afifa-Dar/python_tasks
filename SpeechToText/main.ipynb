# %%
import sounddevice as sd
import os
from scipy.io.wavfile import write

fs = 44100  # Sample rate
seconds = 5 # Duration of recording

myrecording = sd.rec(int(seconds * fs), samplerate=fs, channels=2)
sd.wait()  # Wait until recording is finished
write('output.mp4', fs, myrecording)  # Save as WAV file

# %%
from whisper import load_model
model = load_model("base")
# audio = whisper.load_audio()
text = model.transcribe("voice.m4a")
# Out:
# c:\Users\Lenovo\anaconda3\envs\audio_env\lib\site-packages\whisper\transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Lenovo\Tasks\SpeechToText\main.ipynb Cell 2 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Tasks/SpeechToText/main.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> model = load_model("base")
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Tasks/SpeechToText/main.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> # audio = whisper.load_audio()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Tasks/SpeechToText/main.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> text = model.transcribe("voice.m4a")
#
# ...

# %%
# %pip install translate scipy sounddevice
# Out:
# ...
#   Using cached translate-3.6.1-py2.py3-none-any.whl (12 kB)
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.4 kB 682.7 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/60.4 kB 262.6 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/60.4 kB 262.6 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.4 kB 201.8 kB/s eta 0:00:01
#      -------------------------------------- 60.4/60.4 kB 214.4 kB/s eta 0:00:00
# ...
#   Using cached sounddevice-0.4.6-py3-none-win_amd64.whl (199 kB)
# ...
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached libretranslatepy-2.1.1-py3-none-any.whl (3.2 kB)
# ...
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# ...
#    ---------------------------------------- 0.0/44.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/44.1 MB 1.7 MB/s eta 0:00:27
# ...

# %% [markdown]
# https://www.assemblyai.com/blog/how-to-run-openais-whisper-speech-recognition-model/
#
# https://www.tutorialspoint.com/python_text_processing/python_text_translation.htm
#
# https://github.com/openai/whisper

# %%
import whisper
